# %%
#Nathaniel Graf
#12208076

import numpy as np
import mathplotlib.pyplot as plt

# %%
#Problem 1

#Runge-Kutta 4th order method 
def rk4(fx, t0, y0, t_end, h):
    
    
    pass

#Set initial conditions
x0 = 0.5
y0 = 0.8
t_start = 0
t_end = 10
h = 0.01
