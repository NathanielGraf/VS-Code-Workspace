# %%
#Imports
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
#Load the datasets
arithmetic_data = pd.read_csv('Patterned_Arithmetic_Sequences.csv')
key_data = pd.read_csv('Patterned_Key_Sequences.csv')

#Normalize the data


arithmetic_data.head()
key_data.head()
# Out:
#   Key_Sequences_0 Key_Sequences_1 Key_Sequences_2 Key_Sequences_3  \
# 0               Q               W               E               R
# 1               T               Y               Q               W
# 2               Q               W               E               R
# 3               Q               W               E               R
# 4               Q               W               E               R
#
#   Key_Sequences_4 Key_Sequences_5 Key_Sequences_6 Key_Sequences_7  \
# 0               T               Y               Q               W
# 1               E               R               T               Y
# 2               T               Y               Q               W
# 3               T               Y               Q               W
# 4               T               Y               Q               W
#
#   Key_Sequences_8 Key_Sequences_9  ... Key_Sequences_90 Key_Sequences_91  \
# 0               E               R  ...                Q                W
# ...

# %%
# Then use them like this:
model = keras.Sequential([
    keras.layers.LSTM(64, input_shape=(None, 1)), # 'None' handles variable time steps
    keras.layers.Dense(1)
])
